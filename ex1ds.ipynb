# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvan-174/-Implementation-of-Logistic-Regression-Using-Gradient-Descent/blob/main/ex1ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/SAMPLEIDS.csv")
df
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
df.head()
# Out:
#    SNO    REGNO    NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0    1  1220121    ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1    2  1220122    BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2    3  1220123  CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3    4  1220124    DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4    5  1220125   ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
#
#      M4  TOTAL         AVG
# 0   NaN    NaN         NaN
# 1  56.0  253.0   84.333333
# 2  70.0    NaN    0.000000
# 3  74.0  307.0  102.333333
# 4  92.0  375.0  125.000000

# %%
df.tail()
# Out:
#     SNO    REGNO      NAME       DOB  GENDER      ADDRESS    M1    M2    M3  \
# 16   16  1220136   PRATHAP  20000921    MALE  KANCHIPURAM  86.0  84.0  90.0
# 17   17  1220137     RAGHU  20001109    MALE   POONAMALEE  67.0  64.0  70.0
# 18   18  1220138     RATHI  20001121  FEMALE  KANCHIPURAM  81.0  86.0  90.0
# 19   19  1220139   SARVESH  19990305    MALE    THANDALAM  84.0  87.0   NaN
# 20   20  1220140  SANTHOSH  20001002    MALE  KANCHIPURAM  76.0  69.0  80.0
#
#       M4  TOTAL         AVG
# 16  86.0  346.0  115.333333
# 17   NaN  201.0   67.000000
# 18  81.0  338.0  112.666667
# 19  84.0    NaN    0.000000
# 20  76.0  301.0  100.333333

# %%
df.isnull().sum()
# Out:
# SNO        0
# REGNO      0
# NAME       1
# DOB        0
# GENDER     1
# ADDRESS    1
# M1         3
# M2         2
# M3         4
# M4         3
# TOTAL      5
# AVG        1
# dtype: int64

# %%
df.isnull().any()
# Out:
# SNO        False
# REGNO      False
# NAME        True
# DOB        False
# GENDER      True
# ADDRESS     True
# M1          True
# M2          True
# M3          True
# M4          True
# TOTAL       True
# AVG         True
# dtype: bool

# %%
df.dropna()
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# 11   11  1220131      KANI  2000-11-21  FEMALE      CHITHUR  96.0  95.0  96.0
# 14   14  1220134      NANI    20001109    MALE   POONAMALEE  79.0  77.0  80.0
# 16   16  1220136   PRATHAP    20000921    MALE  KANCHIPURAM  86.0  84.0  90.0
# ...

# %%
df.fillna(1)
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   1.0  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   1.0   1.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
df.fillna(method="ffill")
# Out:
# <ipython-input-8-5a0d178a1f3e>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  56.0  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# ...

# %%
df.fillna(method="bfill")
# Out:
# <ipython-input-10-6bd2f34f2c60>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  74.0  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# ...

# %%
df.fillna({'NAME':'SAM','GENDER':'MALE','ADDRESS':'TAMBARAM','M1':80.0,'M2':85.,'M3':87.0,'M4':88.0,'TOTAL':340.0,'AVG':85.00})
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  80.0  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0  85.0  87.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
ir=pd.read_csv("/content/iris.csv")
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import seaborn as sns
sns.boxplot(x='sepal_width',data=ir)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
#IQR
q1=ir.sepal_width.quantile(0.25)
q3=ir.sepal_width.quantile(0.75)
iqr=q3-q1
print(iqr)
# Out:
# 0.5

# %%
rid=ir[((ir.sepal_width<(q1-1.5*iqr))|(ir.sepal_width>(q3+1.5*iqr)))]
rid['sepal_width']
# Out:
# 15    4.4
# 32    4.1
# 33    4.2
# 60    2.0
# Name: sepal_width, dtype: float64

# %%
delid=ir[~((ir.sepal_width<(q1-1.5*iqr))|(ir.sepal_width>(q3+1.5*iqr)))]
delid
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [146 rows x 5 columns]

# %%
sns.boxplot(x='sepal_width',data=delid)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

zdata=pd.read_csv("/content/heights.csv")
zdata
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
z = np.abs(stats.zscore(zdata['height']))
z
# Out:
# 0     0.055998
# 1     0.317320
# 2     0.354652
# 3     0.205325
# 4     0.429315
# 5     0.242656
# 6     0.055998
# 7     0.167993
# 8     0.391983
# 9     3.154532
# 10    0.018666
# 11    0.167993
# 12    1.810589
# 13    0.205325
# Name: height, dtype: float64
